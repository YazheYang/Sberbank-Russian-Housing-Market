# %% [markdown]
# # Mini project 1 - Basic Data Analytics with Pandas

# %% [markdown]
# In the first week, we’ll practice data exploration and data analysis in Python with a real-world dataset – Sberbank data, which is available in the [Sberbank Russian Housing Market Kaggle competition](https://www.kaggle.com/c/sberbank-russian-housing-market). Sberbank dataset contains rich and messy data about Russian's housing market. This real-world data will provide you concrete practices for getting started with python.

# %% [markdown]
# This step-by-step mini project will cover the most essential and useful techniques for data analysis in solving a real-world problem with key Python data analysis libraries: pandas and numpy. We’ll go through data loading and data frame creation, selection and query, grouping and function applying, plotting and writing data to file.

# %%
# Start with importing essentials
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Question 1: Read the train set and test set of Sberbank dataset from the train.csv and test.csv, and call them train_data and test_data. **
#
# Hint: You can read data from a CSV file using the read_csv function in pandas. By default, it assumes that the fields are comma-separated.

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      cafe_count_5000_price_2500  \
# 0       NaN       NaN    ...                               9
# 1       NaN       NaN    ...                              15
# 2       NaN       NaN    ...                              10
# 3       NaN       NaN    ...                              11
# 4       NaN       NaN    ...                             319
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
# [5 rows x 292 columns]

# %%
test_data.tail()
# Out:
#          id   timestamp  full_sq  life_sq  floor  max_floor  material  \
# 7657  38131  2016-05-26    52.20     31.8     10         12         5
# 7658  38132  2016-05-28    54.09      NaN     14          0         1
# 7659  38133  2016-05-30    41.08      1.0     12          1         1
# 7660  38134  2016-05-30    34.80     19.8      8          9         5
# 7661  38135  2016-05-30    63.00     43.8      5          5         1
#
#       build_year  num_room  kitch_sq        ...          \
# 7657      1973.0         2       9.1        ...
# 7658         NaN         2       0.0        ...
# 7659         1.0         1       1.0        ...
# 7660      1977.0         1       6.4        ...
# 7661      1973.0         3       7.1        ...
#
#       cafe_count_5000_price_1500 cafe_count_5000_price_2500  \
# 7657                          81                         28
# 7658                           1                          2
# 7659                         636                        371
# 7660                          16                          7
# 7661                          31                         11
#
#      cafe_count_5000_price_4000  cafe_count_5000_price_high  \
# 7657                          1                           1
# 7658                          1                           0
# 7659                        141                          26
# 7660                          2                           0
# 7661                          1                           0
#
#       big_church_count_5000  church_count_5000  mosque_count_5000  \
# 7657                      8                 39                  2
# 7658                      0                 10                  0
# 7659                    150                249                  2
# 7660                      5                 11                  0
# 7661                      6                 26                  1
#
#       leisure_count_5000  sport_count_5000  market_count_5000
# 7657                   3                75                 12
# 7658                   0                 0                  0
# 7659                 105               203                 13
# 7660                   2                43                 10
# 7661                   4                42                 11
#
# [5 rows x 291 columns]

# %% [markdown]
# ** Question 2: Merge train and test to one dataframe and call it full_data. **
#
# Hint: The new dataframe should have the rows from train_data followed by rows from test_data. Refer to [merge, join, and concatenate](https://pandas.pydata.org/pandas-docs/stable/merging.html).

# %%
full_data = pd.concat([train_data,test_data], ignore_index=True)
#full_data = train_data.append(test_data, ignore_index=True)

# %% [markdown]
# ***For the rest questions, if not specified, we'll do practice on train_data. Let's create a dataframe called df from train_data.***

# %%
df = train_data

# %% [markdown]
# ** Question 3: Preview the first 10 columns with head().**
#
# Hint: You can change the number of rows displayed by specifying a number. There is a similar function tail(), which will show you the last columns of a dataframe.

# %%
df.head(10)
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
# 5   6  2011-09-06       67     46.0   14.0        NaN       NaN         NaN
# 6   7  2011-09-08       25     14.0   10.0        NaN       NaN         NaN
# 7   8  2011-09-09       44     44.0    5.0        NaN       NaN         NaN
# 8   9  2011-09-10       42     27.0    5.0        NaN       NaN         NaN
# 9  10  2011-09-13       36     21.0    9.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      cafe_count_5000_price_2500  \
# 0       NaN       NaN    ...                               9
# 1       NaN       NaN    ...                              15
# 2       NaN       NaN    ...                              10
# 3       NaN       NaN    ...                              11
# 4       NaN       NaN    ...                             319
# 5       NaN       NaN    ...                              62
# 6       NaN       NaN    ...                              81
# 7       NaN       NaN    ...                               9
# 8       NaN       NaN    ...                              19
# 9       NaN       NaN    ...                              19
#
#   cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                          4                          0
# 1                          3                          0
# 2                          3                          0
# 3                          2                          1
# 4                        108                         17
# 5                         14                          1
# 6                         16                          3
# 7                          4                          0
# 8                          8                          1
# 9                         13                          0
#
#    big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                     13                 22                  1
# 1                     15                 29                  1
# 2                     11                 27                  0
# 3                      4                  4                  0
# 4                    135                236                  2
# 5                     53                 78                  1
# 6                     38                 80                  1
# 7                     11                 18                  1
# 8                     18                 34                  1
# 9                     10                 20                  1
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
# 5                  20               113                 17    9100000
# 6                  27               127                  8    5500000
# 7                   0                47                  4    2000000
# 8                   3                85                 11    5300000
# 9                   3                67                  1    2000000
#
# [10 rows x 292 columns]

# %% [markdown]
# **Question 4: How many columns and rows are there in the data?**

# %%
df.shape
# There are 30471 rows and 292 columns in the data.
# Out:
# (30471, 292)

# %% [markdown]
# **Question 5: Which features are available in the data? Display the features.**
#
# Hint: The features are the column names. You can print them out.

# %%
df.columns.values
# Out:
# array(['id', 'timestamp', 'full_sq', 'life_sq', 'floor', 'max_floor',
#        'material', 'build_year', 'num_room', 'kitch_sq', 'state',
#        'product_type', 'sub_area', 'area_m', 'raion_popul',
#        'green_zone_part', 'indust_part', 'children_preschool',
#        'preschool_quota', 'preschool_education_centers_raion',
#        'children_school', 'school_quota', 'school_education_centers_raion',
#        'school_education_centers_top_20_raion', 'hospital_beds_raion',
#        'healthcare_centers_raion', 'university_top_20_raion',
#        'sport_objects_raion', 'additional_education_raion',
#        'culture_objects_top_25', 'culture_objects_top_25_raion',
#        'shopping_centers_raion', 'office_raion',
#        'thermal_power_plant_raion', 'incineration_raion',
#        'oil_chemistry_raion', 'radiation_raion', 'railroad_terminal_raion',
#        'big_market_raion', 'nuclear_reactor_raion',
#        'detention_facility_raion', 'full_all', 'male_f', 'female_f',
#        'young_all', 'young_male', 'young_female', 'work_all', 'work_male',
#        'work_female', 'ekder_all', 'ekder_male', 'ekder_female', '0_6_all',
#        '0_6_male', '0_6_female', '7_14_all', '7_14_male', '7_14_female',
#        '0_17_all', '0_17_male', '0_17_female', '16_29_all', '16_29_male',
#        '16_29_female', '0_13_all', '0_13_male', '0_13_female',
#        'raion_build_count_with_material_info', 'build_count_block',
#        'build_count_wood', 'build_count_frame', 'build_count_brick',
#        'build_count_monolith', 'build_count_panel', 'build_count_foam',
#        'build_count_slag', 'build_count_mix',
#        'raion_build_count_with_builddate_info', 'build_count_before_1920',
#        'build_count_1921-1945', 'build_count_1946-1970',
#        'build_count_1971-1995', 'build_count_after_1995', 'ID_metro',
#        'metro_min_avto', 'metro_km_avto', 'metro_min_walk',
#        'metro_km_walk', 'kindergarten_km', 'school_km', 'park_km',
#        'green_zone_km', 'industrial_km', 'water_treatment_km',
#        'cemetery_km', 'incineration_km', 'railroad_station_walk_km',
#        'railroad_station_walk_min', 'ID_railroad_station_walk',
#        'railroad_station_avto_km', 'railroad_station_avto_min',
#        'ID_railroad_station_avto', 'public_transport_station_km',
#        'public_transport_station_min_walk', 'water_km', 'water_1line',
#        'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km', 'kremlin_km',
#        'big_road1_km', 'ID_big_road1', 'big_road1_1line', 'big_road2_km',
#        'ID_big_road2', 'railroad_km', 'railroad_1line',
#        'zd_vokzaly_avto_km', 'ID_railroad_terminal',
#        'bus_terminal_avto_km', 'ID_bus_terminal', 'oil_chemistry_km',
#        'nuclear_reactor_km', 'radiation_km', 'power_transmission_line_km',
#        'thermal_power_plant_km', 'ts_km', 'big_market_km',
#        'market_shop_km', 'fitness_km', 'swim_pool_km', 'ice_rink_km',
#        'stadium_km', 'basketball_km', 'hospice_morgue_km',
#        'detention_facility_km', 'public_healthcare_km', 'university_km',
#        'workplaces_km', 'shopping_centers_km', 'office_km',
#        'additional_education_km', 'preschool_km', 'big_church_km',
#        'church_synagogue_km', 'mosque_km', 'theater_km', 'museum_km',
#        'exhibition_km', 'catering_km', 'ecology', 'green_part_500',
#        'prom_part_500', 'office_count_500', 'office_sqm_500',
#        'trc_count_500', 'trc_sqm_500', 'cafe_count_500',
#        'cafe_sum_500_min_price_avg', 'cafe_sum_500_max_price_avg',
#        'cafe_avg_price_500', 'cafe_count_500_na_price',
#        'cafe_count_500_price_500', 'cafe_count_500_price_1000',
#        'cafe_count_500_price_1500', 'cafe_count_500_price_2500',
#        'cafe_count_500_price_4000', 'cafe_count_500_price_high',
#        'big_church_count_500', 'church_count_500', 'mosque_count_500',
#        'leisure_count_500', 'sport_count_500', 'market_count_500',
#        'green_part_1000', 'prom_part_1000', 'office_count_1000',
#        'office_sqm_1000', 'trc_count_1000', 'trc_sqm_1000',
#        'cafe_count_1000', 'cafe_sum_1000_min_price_avg',
#        'cafe_sum_1000_max_price_avg', 'cafe_avg_price_1000',
#        'cafe_count_1000_na_price', 'cafe_count_1000_price_500',
#        'cafe_count_1000_price_1000', 'cafe_count_1000_price_1500',
#        'cafe_count_1000_price_2500', 'cafe_count_1000_price_4000',
#        'cafe_count_1000_price_high', 'big_church_count_1000',
#        'church_count_1000', 'mosque_count_1000', 'leisure_count_1000',
#        'sport_count_1000', 'market_count_1000', 'green_part_1500',
#        'prom_part_1500', 'office_count_1500', 'office_sqm_1500',
#        'trc_count_1500', 'trc_sqm_1500', 'cafe_count_1500',
#        'cafe_sum_1500_min_price_avg', 'cafe_sum_1500_max_price_avg',
#        'cafe_avg_price_1500', 'cafe_count_1500_na_price',
#        'cafe_count_1500_price_500', 'cafe_count_1500_price_1000',
#        'cafe_count_1500_price_1500', 'cafe_count_1500_price_2500',
#        'cafe_count_1500_price_4000', 'cafe_count_1500_price_high',
#        'big_church_count_1500', 'church_count_1500', 'mosque_count_1500',
#        'leisure_count_1500', 'sport_count_1500', 'market_count_1500',
#        'green_part_2000', 'prom_part_2000', 'office_count_2000',
#        'office_sqm_2000', 'trc_count_2000', 'trc_sqm_2000',
#        'cafe_count_2000', 'cafe_sum_2000_min_price_avg',
#        'cafe_sum_2000_max_price_avg', 'cafe_avg_price_2000',
#        'cafe_count_2000_na_price', 'cafe_count_2000_price_500',
#        'cafe_count_2000_price_1000', 'cafe_count_2000_price_1500',
#        'cafe_count_2000_price_2500', 'cafe_count_2000_price_4000',
#        'cafe_count_2000_price_high', 'big_church_count_2000',
#        'church_count_2000', 'mosque_count_2000', 'leisure_count_2000',
#        'sport_count_2000', 'market_count_2000', 'green_part_3000',
#        'prom_part_3000', 'office_count_3000', 'office_sqm_3000',
#        'trc_count_3000', 'trc_sqm_3000', 'cafe_count_3000',
#        'cafe_sum_3000_min_price_avg', 'cafe_sum_3000_max_price_avg',
#        'cafe_avg_price_3000', 'cafe_count_3000_na_price',
#        'cafe_count_3000_price_500', 'cafe_count_3000_price_1000',
#        'cafe_count_3000_price_1500', 'cafe_count_3000_price_2500',
#        'cafe_count_3000_price_4000', 'cafe_count_3000_price_high',
#        'big_church_count_3000', 'church_count_3000', 'mosque_count_3000',
#        'leisure_count_3000', 'sport_count_3000', 'market_count_3000',
#        'green_part_5000', 'prom_part_5000', 'office_count_5000',
#        'office_sqm_5000', 'trc_count_5000', 'trc_sqm_5000',
#        'cafe_count_5000', 'cafe_sum_5000_min_price_avg',
#        'cafe_sum_5000_max_price_avg', 'cafe_avg_price_5000',
#        'cafe_count_5000_na_price', 'cafe_count_5000_price_500',
#        'cafe_count_5000_price_1000', 'cafe_count_5000_price_1500',
#        'cafe_count_5000_price_2500', 'cafe_count_5000_price_4000',
#        'cafe_count_5000_price_high', 'big_church_count_5000',
#        'church_count_5000', 'mosque_count_5000', 'leisure_count_5000',
#        'sport_count_5000', 'market_count_5000', 'price_doc'], dtype=object)

# %% [markdown]
# **Question 6: What's the data type of each column? Save the datatype as data_type.**

# %%
data_type = df.dtypes

# %%
for i in range(len(data_type)):
    print (data_type.index[i],data_type[i])
# Out:
# ('id', dtype('int64'))
# ('timestamp', dtype('O'))
# ('full_sq', dtype('int64'))
# ('life_sq', dtype('float64'))
# ('floor', dtype('float64'))
# ('max_floor', dtype('float64'))
# ('material', dtype('float64'))
# ('build_year', dtype('float64'))
# ('num_room', dtype('float64'))
# ('kitch_sq', dtype('float64'))
# ('state', dtype('float64'))
# ('product_type', dtype('O'))
# ('sub_area', dtype('O'))
# ('area_m', dtype('float64'))
# ('raion_popul', dtype('int64'))
# ('green_zone_part', dtype('float64'))
# ('indust_part', dtype('float64'))
# ('children_preschool', dtype('int64'))
# ('preschool_quota', dtype('float64'))
# ('preschool_education_centers_raion', dtype('int64'))
# ('children_school', dtype('int64'))
# ('school_quota', dtype('float64'))
# ('school_education_centers_raion', dtype('int64'))
# ('school_education_centers_top_20_raion', dtype('int64'))
# ('hospital_beds_raion', dtype('float64'))
# ('healthcare_centers_raion', dtype('int64'))
# ('university_top_20_raion', dtype('int64'))
# ('sport_objects_raion', dtype('int64'))
# ('additional_education_raion', dtype('int64'))
# ('culture_objects_top_25', dtype('O'))
# ('culture_objects_top_25_raion', dtype('int64'))
# ('shopping_centers_raion', dtype('int64'))
# ('office_raion', dtype('int64'))
# ('thermal_power_plant_raion', dtype('O'))
# ('incineration_raion', dtype('O'))
# ('oil_chemistry_raion', dtype('O'))
# ('radiation_raion', dtype('O'))
# ('railroad_terminal_raion', dtype('O'))
# ('big_market_raion', dtype('O'))
# ('nuclear_reactor_raion', dtype('O'))
# ('detention_facility_raion', dtype('O'))
# ('full_all', dtype('int64'))
# ('male_f', dtype('int64'))
# ('female_f', dtype('int64'))
# ('young_all', dtype('int64'))
# ('young_male', dtype('int64'))
# ('young_female', dtype('int64'))
# ('work_all', dtype('int64'))
# ('work_male', dtype('int64'))
# ('work_female', dtype('int64'))
# ('ekder_all', dtype('int64'))
# ('ekder_male', dtype('int64'))
# ('ekder_female', dtype('int64'))
# ('0_6_all', dtype('int64'))
# ('0_6_male', dtype('int64'))
# ('0_6_female', dtype('int64'))
# ('7_14_all', dtype('int64'))
# ('7_14_male', dtype('int64'))
# ('7_14_female', dtype('int64'))
# ('0_17_all', dtype('int64'))
# ('0_17_male', dtype('int64'))
# ('0_17_female', dtype('int64'))
# ('16_29_all', dtype('int64'))
# ('16_29_male', dtype('int64'))
# ('16_29_female', dtype('int64'))
# ('0_13_all', dtype('int64'))
# ('0_13_male', dtype('int64'))
# ('0_13_female', dtype('int64'))
# ('raion_build_count_with_material_info', dtype('float64'))
# ('build_count_block', dtype('float64'))
# ('build_count_wood', dtype('float64'))
# ('build_count_frame', dtype('float64'))
# ('build_count_brick', dtype('float64'))
# ('build_count_monolith', dtype('float64'))
# ('build_count_panel', dtype('float64'))
# ('build_count_foam', dtype('float64'))
# ('build_count_slag', dtype('float64'))
# ('build_count_mix', dtype('float64'))
# ('raion_build_count_with_builddate_info', dtype('float64'))
# ('build_count_before_1920', dtype('float64'))
# ('build_count_1921-1945', dtype('float64'))
# ('build_count_1946-1970', dtype('float64'))
# ('build_count_1971-1995', dtype('float64'))
# ('build_count_after_1995', dtype('float64'))
# ('ID_metro', dtype('int64'))
# ('metro_min_avto', dtype('float64'))
# ('metro_km_avto', dtype('float64'))
# ('metro_min_walk', dtype('float64'))
# ('metro_km_walk', dtype('float64'))
# ('kindergarten_km', dtype('float64'))
# ('school_km', dtype('float64'))
# ('park_km', dtype('float64'))
# ('green_zone_km', dtype('float64'))
# ('industrial_km', dtype('float64'))
# ('water_treatment_km', dtype('float64'))
# ('cemetery_km', dtype('float64'))
# ('incineration_km', dtype('float64'))
# ('railroad_station_walk_km', dtype('float64'))
# ('railroad_station_walk_min', dtype('float64'))
# ('ID_railroad_station_walk', dtype('float64'))
# ('railroad_station_avto_km', dtype('float64'))
# ('railroad_station_avto_min', dtype('float64'))
# ('ID_railroad_station_avto', dtype('int64'))
# ('public_transport_station_km', dtype('float64'))
# ('public_transport_station_min_walk', dtype('float64'))
# ('water_km', dtype('float64'))
# ('water_1line', dtype('O'))
# ('mkad_km', dtype('float64'))
# ('ttk_km', dtype('float64'))
# ('sadovoe_km', dtype('float64'))
# ('bulvar_ring_km', dtype('float64'))
# ('kremlin_km', dtype('float64'))
# ('big_road1_km', dtype('float64'))
# ('ID_big_road1', dtype('int64'))
# ('big_road1_1line', dtype('O'))
# ('big_road2_km', dtype('float64'))
# ('ID_big_road2', dtype('int64'))
# ('railroad_km', dtype('float64'))
# ('railroad_1line', dtype('O'))
# ('zd_vokzaly_avto_km', dtype('float64'))
# ('ID_railroad_terminal', dtype('int64'))
# ('bus_terminal_avto_km', dtype('float64'))
# ('ID_bus_terminal', dtype('int64'))
# ('oil_chemistry_km', dtype('float64'))
# ('nuclear_reactor_km', dtype('float64'))
# ('radiation_km', dtype('float64'))
# ('power_transmission_line_km', dtype('float64'))
# ('thermal_power_plant_km', dtype('float64'))
# ('ts_km', dtype('float64'))
# ('big_market_km', dtype('float64'))
# ('market_shop_km', dtype('float64'))
# ('fitness_km', dtype('float64'))
# ('swim_pool_km', dtype('float64'))
# ('ice_rink_km', dtype('float64'))
# ('stadium_km', dtype('float64'))
# ('basketball_km', dtype('float64'))
# ('hospice_morgue_km', dtype('float64'))
# ('detention_facility_km', dtype('float64'))
# ('public_healthcare_km', dtype('float64'))
# ('university_km', dtype('float64'))
# ('workplaces_km', dtype('float64'))
# ('shopping_centers_km', dtype('float64'))
# ('office_km', dtype('float64'))
# ('additional_education_km', dtype('float64'))
# ('preschool_km', dtype('float64'))
# ('big_church_km', dtype('float64'))
# ('church_synagogue_km', dtype('float64'))
# ('mosque_km', dtype('float64'))
# ('theater_km', dtype('float64'))
# ('museum_km', dtype('float64'))
# ('exhibition_km', dtype('float64'))
# ('catering_km', dtype('float64'))
# ('ecology', dtype('O'))
# ('green_part_500', dtype('float64'))
# ('prom_part_500', dtype('float64'))
# ('office_count_500', dtype('int64'))
# ('office_sqm_500', dtype('int64'))
# ('trc_count_500', dtype('int64'))
# ('trc_sqm_500', dtype('int64'))
# ('cafe_count_500', dtype('int64'))
# ('cafe_sum_500_min_price_avg', dtype('float64'))
# ('cafe_sum_500_max_price_avg', dtype('float64'))
# ('cafe_avg_price_500', dtype('float64'))
# ('cafe_count_500_na_price', dtype('int64'))
# ('cafe_count_500_price_500', dtype('int64'))
# ('cafe_count_500_price_1000', dtype('int64'))
# ('cafe_count_500_price_1500', dtype('int64'))
# ('cafe_count_500_price_2500', dtype('int64'))
# ('cafe_count_500_price_4000', dtype('int64'))
# ('cafe_count_500_price_high', dtype('int64'))
# ('big_church_count_500', dtype('int64'))
# ('church_count_500', dtype('int64'))
# ('mosque_count_500', dtype('int64'))
# ('leisure_count_500', dtype('int64'))
# ('sport_count_500', dtype('int64'))
# ('market_count_500', dtype('int64'))
# ('green_part_1000', dtype('float64'))
# ('prom_part_1000', dtype('float64'))
# ('office_count_1000', dtype('int64'))
# ('office_sqm_1000', dtype('int64'))
# ('trc_count_1000', dtype('int64'))
# ('trc_sqm_1000', dtype('int64'))
# ('cafe_count_1000', dtype('int64'))
# ('cafe_sum_1000_min_price_avg', dtype('float64'))
# ('cafe_sum_1000_max_price_avg', dtype('float64'))
# ('cafe_avg_price_1000', dtype('float64'))
# ('cafe_count_1000_na_price', dtype('int64'))
# ('cafe_count_1000_price_500', dtype('int64'))
# ('cafe_count_1000_price_1000', dtype('int64'))
# ('cafe_count_1000_price_1500', dtype('int64'))
# ('cafe_count_1000_price_2500', dtype('int64'))
# ('cafe_count_1000_price_4000', dtype('int64'))
# ('cafe_count_1000_price_high', dtype('int64'))
# ('big_church_count_1000', dtype('int64'))
# ('church_count_1000', dtype('int64'))
# ('mosque_count_1000', dtype('int64'))
# ('leisure_count_1000', dtype('int64'))
# ('sport_count_1000', dtype('int64'))
# ('market_count_1000', dtype('int64'))
# ('green_part_1500', dtype('float64'))
# ('prom_part_1500', dtype('float64'))
# ('office_count_1500', dtype('int64'))
# ('office_sqm_1500', dtype('int64'))
# ('trc_count_1500', dtype('int64'))
# ('trc_sqm_1500', dtype('int64'))
# ('cafe_count_1500', dtype('int64'))
# ('cafe_sum_1500_min_price_avg', dtype('float64'))
# ('cafe_sum_1500_max_price_avg', dtype('float64'))
# ('cafe_avg_price_1500', dtype('float64'))
# ('cafe_count_1500_na_price', dtype('int64'))
# ('cafe_count_1500_price_500', dtype('int64'))
# ('cafe_count_1500_price_1000', dtype('int64'))
# ('cafe_count_1500_price_1500', dtype('int64'))
# ('cafe_count_1500_price_2500', dtype('int64'))
# ('cafe_count_1500_price_4000', dtype('int64'))
# ('cafe_count_1500_price_high', dtype('int64'))
# ('big_church_count_1500', dtype('int64'))
# ('church_count_1500', dtype('int64'))
# ('mosque_count_1500', dtype('int64'))
# ('leisure_count_1500', dtype('int64'))
# ('sport_count_1500', dtype('int64'))
# ('market_count_1500', dtype('int64'))
# ('green_part_2000', dtype('float64'))
# ('prom_part_2000', dtype('float64'))
# ('office_count_2000', dtype('int64'))
# ('office_sqm_2000', dtype('int64'))
# ('trc_count_2000', dtype('int64'))
# ('trc_sqm_2000', dtype('int64'))
# ('cafe_count_2000', dtype('int64'))
# ('cafe_sum_2000_min_price_avg', dtype('float64'))
# ('cafe_sum_2000_max_price_avg', dtype('float64'))
# ('cafe_avg_price_2000', dtype('float64'))
# ('cafe_count_2000_na_price', dtype('int64'))
# ('cafe_count_2000_price_500', dtype('int64'))
# ('cafe_count_2000_price_1000', dtype('int64'))
# ('cafe_count_2000_price_1500', dtype('int64'))
# ('cafe_count_2000_price_2500', dtype('int64'))
# ('cafe_count_2000_price_4000', dtype('int64'))
# ('cafe_count_2000_price_high', dtype('int64'))
# ('big_church_count_2000', dtype('int64'))
# ('church_count_2000', dtype('int64'))
# ('mosque_count_2000', dtype('int64'))
# ('leisure_count_2000', dtype('int64'))
# ('sport_count_2000', dtype('int64'))
# ('market_count_2000', dtype('int64'))
# ('green_part_3000', dtype('float64'))
# ('prom_part_3000', dtype('float64'))
# ('office_count_3000', dtype('int64'))
# ('office_sqm_3000', dtype('int64'))
# ('trc_count_3000', dtype('int64'))
# ('trc_sqm_3000', dtype('int64'))
# ('cafe_count_3000', dtype('int64'))
# ('cafe_sum_3000_min_price_avg', dtype('float64'))
# ('cafe_sum_3000_max_price_avg', dtype('float64'))
# ('cafe_avg_price_3000', dtype('float64'))
# ('cafe_count_3000_na_price', dtype('int64'))
# ('cafe_count_3000_price_500', dtype('int64'))
# ('cafe_count_3000_price_1000', dtype('int64'))
# ('cafe_count_3000_price_1500', dtype('int64'))
# ('cafe_count_3000_price_2500', dtype('int64'))
# ('cafe_count_3000_price_4000', dtype('int64'))
# ('cafe_count_3000_price_high', dtype('int64'))
# ('big_church_count_3000', dtype('int64'))
# ('church_count_3000', dtype('int64'))
# ('mosque_count_3000', dtype('int64'))
# ('leisure_count_3000', dtype('int64'))
# ('sport_count_3000', dtype('int64'))
# ('market_count_3000', dtype('int64'))
# ('green_part_5000', dtype('float64'))
# ('prom_part_5000', dtype('float64'))
# ('office_count_5000', dtype('int64'))
# ('office_sqm_5000', dtype('int64'))
# ('trc_count_5000', dtype('int64'))
# ('trc_sqm_5000', dtype('int64'))
# ('cafe_count_5000', dtype('int64'))
# ('cafe_sum_5000_min_price_avg', dtype('float64'))
# ('cafe_sum_5000_max_price_avg', dtype('float64'))
# ('cafe_avg_price_5000', dtype('float64'))
# ('cafe_count_5000_na_price', dtype('int64'))
# ('cafe_count_5000_price_500', dtype('int64'))
# ('cafe_count_5000_price_1000', dtype('int64'))
# ('cafe_count_5000_price_1500', dtype('int64'))
# ('cafe_count_5000_price_2500', dtype('int64'))
# ('cafe_count_5000_price_4000', dtype('int64'))
# ('cafe_count_5000_price_high', dtype('int64'))
# ('big_church_count_5000', dtype('int64'))
# ('church_count_5000', dtype('int64'))
# ('mosque_count_5000', dtype('int64'))
# ('leisure_count_5000', dtype('int64'))
# ('sport_count_5000', dtype('int64'))
# ('market_count_5000', dtype('int64'))
# ('price_doc', dtype('int64'))

# %% [markdown]
# **Question 7: Which variables are numerical variables (excluding 'id')? Put all the numerical variable in list.**
#
# Hint: Use the index of the data_type we just created in Q5. The data type of numerical variables should be int or float. Remenber to remove the 'id'.

# %%
num_var = data_type[data_type!='object'].index.tolist()
num_var.remove('id')
print len(num_var)
# Out:
# 275

# %% [markdown]
# **Question 8: Select the first 5 rows with 'id' (the 1st column) and 'price_doc' (the last column) columns from the data. **
#
# Hint: You can find out several ways to solve this question.

# %%
df[:5][['id', 'price_doc']]
# df.loc[:4, ['id', 'price_doc']]
# df.iloc[:5, [0, -1]]
# Out:
#    id  price_doc
# 0   1    5850000
# 1   2    6000000
# 2   3    5700000
# 3   4   13100000
# 4   5   16331452

# %% [markdown]
# **Question 9: Select the rows with the full area larger than 10 and smaller than 1500. Full area is indicated by 'full_sq'.**
#
# Hint: You can use boolean indexing or query. Try both methods.

# %%
#boolean indexing
df[(df.full_sq>10)&(df.full_sq<1500)]
#query
df.query('full_sq>10 and full_sq<1500')
# Out:
#           id   timestamp  full_sq  life_sq  floor  max_floor  material  \
# 0          1  2011-08-20       43     27.0    4.0        NaN       NaN
# 1          2  2011-08-23       34     19.0    3.0        NaN       NaN
# 2          3  2011-08-27       43     29.0    2.0        NaN       NaN
# 3          4  2011-09-01       89     50.0    9.0        NaN       NaN
# 4          5  2011-09-05       77     77.0    4.0        NaN       NaN
# 5          6  2011-09-06       67     46.0   14.0        NaN       NaN
# 6          7  2011-09-08       25     14.0   10.0        NaN       NaN
# 7          8  2011-09-09       44     44.0    5.0        NaN       NaN
# 8          9  2011-09-10       42     27.0    5.0        NaN       NaN
# 9         10  2011-09-13       36     21.0    9.0        NaN       NaN
# 10        11  2011-09-16       36     19.0   12.0        NaN       NaN
# 11        12  2011-09-16       38     19.0   11.0        NaN       NaN
# 12        13  2011-09-17       43     28.0    4.0        NaN       NaN
# 13        14  2011-09-19       31     31.0    4.0        NaN       NaN
# 14        15  2011-09-19       31     21.0    3.0        NaN       NaN
# 15        16  2011-09-20       51     31.0   15.0        NaN       NaN
# 16        17  2011-09-20       47     31.0    4.0        NaN       NaN
# 17        18  2011-09-20       42     28.0    2.0        NaN       NaN
# 18        19  2011-09-22       59     33.0   10.0        NaN       NaN
# 19        20  2011-09-22       44     29.0    4.0        NaN       NaN
# 20        21  2011-09-22       74     44.0   10.0        NaN       NaN
# 21        22  2011-09-22       39     39.0    7.0        NaN       NaN
# 22        23  2011-09-23       48     34.0    6.0        NaN       NaN
# 23        24  2011-09-23       32     18.0    3.0        NaN       NaN
# 24        25  2011-09-23       34     19.0   11.0        NaN       NaN
# 25        26  2011-09-24       45     29.0    9.0        NaN       NaN
# 26        27  2011-09-26       35     20.0    4.0        NaN       NaN
# 27        28  2011-09-26       38     20.0    6.0        NaN       NaN
# 28        29  2011-09-26       73     38.0   15.0        NaN       NaN
# 29        30  2011-09-27       42     27.0    3.0        NaN       NaN
# ...      ...         ...      ...      ...    ...        ...       ...
# 30441  30444  2015-06-27      113      1.0   26.0       26.0       1.0
# 30442  30445  2015-06-27       40     40.0    2.0       12.0       4.0
# 30443  30446  2015-06-27       79      NaN   17.0       17.0       1.0
# 30444  30447  2015-06-27       85      NaN   20.0       25.0       4.0
# 30445  30448  2015-06-27       47     47.0   19.0       25.0       1.0
# 30446  30449  2015-06-27       82     82.0    8.0        8.0       6.0
# 30447  30450  2015-06-27       64      NaN   15.0       17.0       1.0
# 30448  30451  2015-06-27       74      NaN    8.0       17.0       1.0
# 30449  30452  2015-06-27       47     47.0    7.0       25.0       1.0
# 30450  30453  2015-06-29       65      NaN    5.0        0.0       1.0
# 30451  30454  2015-06-29       37      NaN    3.0        3.0       1.0
# 30452  30455  2015-06-29       38     19.0    7.0       17.0       1.0
# 30453  30456  2015-06-29       45      1.0    6.0       15.0       6.0
# 30454  30457  2015-06-29       40     26.0    3.0        9.0       2.0
# 30455  30458  2015-06-29       79     79.0    3.0        3.0       1.0
# 30456  30459  2015-06-29       52     30.0    8.0       14.0       1.0
# 30457  30460  2015-06-29       58     43.0    7.0        9.0       1.0
# 30458  30461  2015-06-29       50      1.0    7.0        7.0       1.0
# 30459  30462  2015-06-29       51      NaN    4.0       17.0       4.0
# 30460  30463  2015-06-29       54     32.0    8.0       16.0       1.0
# 30461  30464  2015-06-30       36     19.0    5.0       16.0       1.0
# 30462  30465  2015-06-30       47     30.0   23.0       25.0       4.0
# 30463  30466  2015-06-30       56     29.0   13.0       14.0       1.0
# 30464  30467  2015-06-30       56     51.0   19.0       19.0       1.0
# 30465  30468  2015-06-30       52      NaN   13.0       17.0       1.0
# 30466  30469  2015-06-30       44     27.0    7.0        9.0       1.0
# 30467  30470  2015-06-30       86     59.0    3.0        9.0       2.0
# 30468  30471  2015-06-30       45      NaN   10.0       20.0       1.0
# 30469  30472  2015-06-30       64     32.0    5.0       15.0       1.0
# 30470  30473  2015-06-30       43     28.0    1.0        9.0       1.0
#
#        build_year  num_room  kitch_sq    ...      cafe_count_5000_price_2500  \
# 0             NaN       NaN       NaN    ...                               9
# 1             NaN       NaN       NaN    ...                              15
# 2             NaN       NaN       NaN    ...                              10
# 3             NaN       NaN       NaN    ...                              11
# 4             NaN       NaN       NaN    ...                             319
# 5             NaN       NaN       NaN    ...                              62
# 6             NaN       NaN       NaN    ...                              81
# 7             NaN       NaN       NaN    ...                               9
# 8             NaN       NaN       NaN    ...                              19
# 9             NaN       NaN       NaN    ...                              19
# 10            NaN       NaN       NaN    ...                               1
# 11            NaN       NaN       NaN    ...                               8
# 12            NaN       NaN       NaN    ...                              13
# 13            NaN       NaN       NaN    ...                             254
# 14            NaN       NaN       NaN    ...                              88
# 15            NaN       NaN       NaN    ...                               6
# 16            NaN       NaN       NaN    ...                              10
# 17            NaN       NaN       NaN    ...                              32
# 18            NaN       NaN       NaN    ...                               1
# 19            NaN       NaN       NaN    ...                               9
# 20            NaN       NaN       NaN    ...                               0
# 21            NaN       NaN       NaN    ...                              18
# 22            NaN       NaN       NaN    ...                              16
# 23            NaN       NaN       NaN    ...                              10
# 24            NaN       NaN       NaN    ...                              20
# 25            NaN       NaN       NaN    ...                              23
# 26            NaN       NaN       NaN    ...                              16
# 27            NaN       NaN       NaN    ...                               1
# 28            NaN       NaN       NaN    ...                              20
# 29            NaN       NaN       NaN    ...                              15
# ...           ...       ...       ...    ...                             ...
# 30441      2015.0       4.0       1.0    ...                             371
# 30442      2015.0       1.0      10.0    ...                               0
# 30443         NaN       3.0      79.0    ...                               7
# 30444      2016.0       3.0       1.0    ...                              13
# 30445      2016.0       1.0       1.0    ...                              99
# 30446      2017.0       2.0       1.0    ...                               2
# 30447         NaN       2.0       1.0    ...                               7
# 30448         NaN       3.0       1.0    ...                               1
# 30449      2015.0       1.0       1.0    ...                              99
# 30450         NaN       2.0       0.0    ...                              20
# 30451         0.0       1.0       1.0    ...                               0
# 30452      2006.0       1.0       7.0    ...                              26
# 30453      2015.0       1.0       1.0    ...                               2
# 30454      1972.0       2.0       5.0    ...                              25
# 30455         NaN       3.0       1.0    ...                               1
# 30456      1992.0       2.0       8.0    ...                              13
# 30457      1979.0       3.0       6.0    ...                               5
# 30458      2015.0       1.0       0.0    ...                              13
# 30459         NaN       2.0       1.0    ...                               7
# 30460      1979.0       2.0       9.0    ...                               8
# 30461      1980.0       1.0       8.0    ...                              41
# 30462      2016.0       1.0      10.0    ...                              99
# 30463      2001.0       2.0      11.0    ...                              14
# 30464      2017.0       2.0       1.0    ...                              25
# 30465         NaN       2.0       1.0    ...                             371
# 30466      1975.0       2.0       6.0    ...                              15
# 30467      1935.0       4.0      10.0    ...                             313
# 30468         NaN       1.0       1.0    ...                               1
# 30469      2003.0       2.0      11.0    ...                              22
# 30470      1968.0       2.0       6.0    ...                               5
#
#       cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 0                              4                          0
# 1                              3                          0
# 2                              3                          0
# 3                              2                          1
# 4                            108                         17
# 5                             14                          1
# 6                             16                          3
# 7                              4                          0
# 8                              8                          1
# 9                             13                          0
# 10                             1                          0
# 11                             3                          0
# 12                             9                          1
# 13                           108                         22
# 14                            19                          2
# 15                             1                          0
# 16                             2                          0
# 17                             6                          0
# 18                             1                          0
# 19                             2                          0
# 20                             0                          0
# 21                             3                          0
# 22                             4                          1
# 23                             1                          0
# 24                             4                          1
# 25                            15                          1
# 26                             5                          0
# 27                             1                          0
# 28                             3                          0
# 29                             2                          0
# ...                          ...                        ...
# 30441                        141                         26
# 30442                          0                          0
# 30443                          2                          0
# 30444                          4                          1
# 30445                         57                         12
# 30446                          2                          0
# 30447                          2                          0
# 30448                          0                          0
# 30449                         57                         12
# 30450                          4                          0
# 30451                          0                          0
# 30452                         12                          0
# 30453                          1                          0
# 30454                          3                          0
# 30455                          1                          0
# 30443                   3                17                  2    7567425
# 30444                   1                38                  5   11438948
# 30445                  13               123                  7   10139368
# 30446                   0                 7                  2    6125400
# 30447                   3                17                  2    6373324
# 30448                   0                 8                  0    6888144
# 30449                  13               123                  7    9227657
# 30450                   3                84                  5   12610000
# 30451                   0                 0                  0    2394300
# 30452                   4                67                  2    6800000
# 30453                   0                20                  3    4066740
# 30454                   8                90                  4    6300000
# 30455                   1                10                  0    9014972
# 30456                   1                42                  6    1000000
# 30457                   1                36                  1    7800000
# 30458                   3                35                  3    6370777
# 30459                   3                17                  2    5778893
# 30460                   1                32                  8    9500000
# 30461                   6                80                  6    5000000
# 30462                  13               123                  7   10544070
# 30463                   1                53                  6   12000000
# 30464                   4                90                  6   10262010
# 30465                 105               203                 13    6750554
# 30466                   2                84                  6    7400000
# 30467                  82               171                 15   25000000
# 30468                   1                11                  1    6970959
# 30469                   4                65                  7   13500000
# 30470                   9                54                 10    5600000
#
# [30470 rows x 292 columns]

# %% [markdown]
# **Question 10: Find the index of the rows with full area ('full_sq') smaller than living area ('life_sq'). Change the 'life_sq' in these rows to NAN.**

# %%
df.loc[df.full_sq < df.life_sq,'life_sq'] = np.NaN

# %% [markdown]
# ** Question 11: Check how many rows in life_sq are NAN? **

# %%
df.life_sq.isnull().sum()
# Out:
# 6420

# %% [markdown]
# **Question 12: The 'product_type' column tells us whether this housing is a owner-occupier purchase or investment. Which type is more common? What's the percentage of each type?**

# %%
df['product_type'].value_counts(normalize=True)
# Out:
# Investment       0.638246
# OwnerOccupier    0.361754
# Name: product_type, dtype: float64

# %%
### method 2
inv = len(df[df.product_type == 'Investment'])
own = len(df[df.product_type == 'OwnerOccupier'])
print 'Number of investment: {}'.format(inv)
print 'Number of owner-occupier: {}'.format(own)
print 'The percentage of investment: {:.2f}'.format(float(inv)/float(df.shape[0]))
print 'The percentage of owner-occupier: {:.2f}'.format(float(own)/float(df.shape[0]))
# Out:
# Number of investment: 19448
# Number of owner-occupier: 11023
# The percentage of investment: 0.64
# The percentage of owner-occupier: 0.36

# %% [markdown]
# The housing of investment is more common in this dataset.

# %% [markdown]
# **Question 13: Group the data by 'product_type' and calculate the median price for each type. The price is indicated by 'price_doc' column.**
#
# Hint: First select the two columns, then group and aggregate. If you choose .aggragate() method, use np.median for the median calculation.

# %%
df.groupby('product_type')['price_doc'].median()
# Out:
# product_type
# Investment       6670000
# OwnerOccupier    5564090
# Name: price_doc, dtype: int64

# %% [markdown]
# ** Question 14: Check how many houses are there in each product type and each state. First group by product_type and then group by state. Name this as grouped**

# %%
grouped = df.groupby(['product_type', 'state'])['price_doc'].size()
grouped
# Out:
# product_type   state
# Investment     1.0       520
#                2.0      5802
#                3.0      5653
#                4.0       413
#                33.0        1
# OwnerOccupier  1.0      4335
#                2.0        42
#                3.0       137
#                4.0         9
# Name: price_doc, dtype: int64

# %%
df.groupby(['product_type','state'])['full_sq'].nlargest(5)
# Out:
# product_type   state
# Investment     1.0    18525    275
#                       17277    220
#                       17710    219
#                       28081    219
#                       15145    215
#                2.0    21697    182
#                       18933    177
#                       21897    159
#                       22665    155
#                       28698    150
# 29277      2014.0       3.0       9.0    ...                               0
# 29302      1973.0       3.0       5.0    ...                             223
# 29310      2012.0       4.0      25.0    ...                               1
# 29329      2010.0       2.0      11.0    ...                              11
# 29340      2007.0       3.0      15.0    ...                               1
# 29399      2013.0       3.0      11.0    ...                               1
# 29417      2011.0       3.0      20.0    ...                              13
# 29437      2013.0       3.0      12.0    ...                               3
# 29496      2014.0       4.0      13.0    ...                              40
# 29541      2013.0       2.0      10.0    ...                               0
# 29578      2011.0       1.0      13.0    ...                              94
# 29660      2011.0       3.0      13.0    ...                              12
# 29669      2013.0       3.0       9.0    ...                               0
# 29673      2013.0       1.0       7.0    ...                               1
# 29709      2011.0       1.0       8.0    ...                             371
# 29732      2014.0       3.0       9.0    ...                               0
# 29748      1958.0       2.0       7.0    ...                              46
# 29804      2009.0       3.0      16.0    ...                              24
# 29837      2014.0       3.0      10.0    ...                               0
# 29847      2010.0       3.0      14.0    ...                              27
# 29870      2013.0       3.0      14.0    ...                               1
# 29880      1961.0       2.0       5.0    ...                              48
# 29888         NaN       2.0       9.0    ...                               5
# 29975      2000.0       3.0      11.0    ...                             297
# 29989      2012.0       1.0      14.0    ...                               2
# 30019      2014.0       2.0      12.0    ...                               1
# 30033      2014.0       1.0       8.0    ...                               0
# 30036      1973.0       2.0       7.0    ...                              14
# 30154      2012.0       3.0      12.0    ...                              12
# 30207      2014.0       1.0       6.0    ...                               1
#
#       cafe_count_5000_price_4000 cafe_count_5000_price_high  \
# 8451                           0                          0
# 8912                           5                          0
# 9113                           3                          0
# 9117                           2                          0
# 9669                           3                          0
# 9690                           9                          2
# 9823                           4                          0
# 9924                           1                          0
# 10006                          8                          1
# 10063                          8                          0
# 10083                          3                          1
# 10138                         81                         12
# 10231                          0                          0
# 10272                          3                          1
# 10295                         75                         16
# 10314                          8                          0
# 10345                          3                          1
# 10552                        130                         24
# 10603                          1                          0
# 10619                          0                          0
# 10694                          6                          1
# 10717                          3                          1
# 10721                          1                          0
# 10752                          9                          3
# 10810                          6                          0
# 10825                          2                          0
# 10845                         33                          4
# 10939                          2                          0
# 10961                         10                          1
# 11011                          4                          1
# ...                          ...                        ...
# 29277                          0                          0
# 29302                         98                         20
# 29310                          2                          0
# 29329                          1                          0
# 29340                          0                          0
# 29399                          1                          0
# 29417                          2                          0
# 29437                          1                          0
# 29496                         12                          3
# 29541                          0                          0
# 29578                         26                          4
# 29660                          5                          0
# 29669                          0                          0
# 29673                          0                          0
# 29709                        141                         26
# 29732                          0                          0
# 29748                          7                          3
# 29804                          3                          1
# 29837                          0                          0
# 29847                          6                          1
# 29870                          0                          0
# 29880                          8                          2
# 29888                          2                          0
# 29975                        121                         24
# 29989                          2                          0
# 30019                          0                          0
# 30033                          0                          0
# 30036                          5                          0
# 30154                          3                          1
# 30207                          0                          0
#
#        big_church_count_5000  church_count_5000  mosque_count_5000  \
# 8451                       0                  7                  0
# 8912                      13                 29                  1
# 9113                      17                 33                  0
# 9117                       6                 25                  0
# 9669                      17                 33                  0
# 9690                      24                 45                  1
# 9823                      18                 37                  0
# 9924                       4                  6                  0
# 10006                      8                 38                  1
# 29804                   4                67                  6   23300000
# 29837                   2                10                  1    8744700
# 29847                   3                92                 12   30300000
# 29870                   0                 3                  0    8253106
# 29880                   9                89                 10    9300000
# 29888                   9                59                 11    6740000
# 29975                  77               170                 13   40000000
# 29989                   0                 6                  1    3035645
# 30019                   0                 2                  1    2755137
# 30033                   2                10                  1    4680000
# 30036                   8                68                 13    9000000
# 30154                   0                32                  3    2000000
# 30207                   0                 3                  1    5869700
#
# [520 rows x 292 columns]

# %%
grouped1 = df.groupby(['product_type', 'state'])['price_doc'].mean()

# %%
grouped1.sort_values(ascending=False)
# Out:
# product_type   state
# Investment     4.0      1.340676e+07
# OwnerOccupier  4.0      1.053271e+07
# Investment     1.0      9.919482e+06
#                33.0     9.000000e+06
# OwnerOccupier  2.0      8.444159e+06
# Investment     3.0      8.083450e+06
# OwnerOccupier  3.0      7.866479e+06
# Investment     2.0      7.050045e+06
# OwnerOccupier  1.0      7.003075e+06
# Name: price_doc, dtype: float64

# %% [markdown]
# **Question 15: Unstack the state index in grouped.**
#
# Hint: Use unstack() to turn the index values in state into column names.

# %%
grouped.unstack('state')
# Out:
# state            1.0     2.0     3.0    4.0   33.0
# product_type
# Investment      520.0  5802.0  5653.0  413.0   1.0
# OwnerOccupier  4335.0    42.0   137.0    9.0   NaN

# %% [markdown]
# **Question 16: Add a new feature called 'room_size', which indicated the average living area in each room of a housing. 'num_room' is the column that shows the number of rooms.**

# %%
df['room_size'] = df ['life_sq']/df['num_room']
df['room_size']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
#            ...
# 30441     0.250000
# 30442    40.000000
# 30443          NaN
# 30444          NaN
# 30445    47.000000
# 30446    41.000000
# 30447          NaN
# 30448          NaN
# 30449    47.000000
# 30450          NaN
# 30451          NaN
# 30452    19.000000
# 30453     1.000000
# 30454    13.000000
# 30455    26.333333
# 30456    15.000000
# 30457    14.333333
# 30458     1.000000
# 30459          NaN
# 30460    16.000000
# 30461    19.000000
# 30462    30.000000
# 30463    14.500000
# 30464    25.500000
# 30465          NaN
# 30466    13.500000
# 30467    14.750000
# 30468          NaN
# 30469    16.000000
# 30470    14.000000
# Name: room_size, Length: 30471, dtype: float64

# %% [markdown]
# **Quesion 17: Change the format of timestamp to '%Y-%m-%d'. **
#
# Hint: For more info about timestamp in pandas, read [this document](https://pandas.pydata.org/pandas-docs/stable/timeseries.html).

# %%
df['timestamp']=pd.to_datetime(df['timestamp'], format='%Y-%m-%d')

# %% [markdown]
# **Question 18: Add new features called 'ts_year' and 'ts_dayofweek', which indicate the year and the number of the day of the week.**
#
# Hint: you can use apply() to apply functions to the data.

# %%
df['ts_year'] = df['timestamp'].dt.year
df['ts_dayofweek'] = df['timestamp'].dt.dayofweek

# %%
df.head()
# Out:
#    id  timestamp  full_sq life_sq  floor  max_floor  material  build_year  \
# 0   1 2011-08-20       43      27    4.0        NaN       NaN         NaN
# 1   2 2011-08-23       34      19    3.0        NaN       NaN         NaN
# 2   3 2011-08-27       43      29    2.0        NaN       NaN         NaN
# 3   4 2011-09-01       89      50    9.0        NaN       NaN         NaN
# 4   5 2011-09-05       77      77    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq      ...       big_church_count_5000 church_count_5000  \
# 0       NaN       NaN      ...                          13                22
# 1       NaN       NaN      ...                          15                29
# 2       NaN       NaN      ...                          11                27
# 3       NaN       NaN      ...                           4                 4
# 4       NaN       NaN      ...                         135               236
#
#   mosque_count_5000  leisure_count_5000  sport_count_5000  market_count_5000  \
# 0                 1                   0                52                  4
# 1                 1                  10                66                 14
# 2                 0                   4                67                 10
# 3                 0                   0                26                  3
# 4                 2                  91               195                 14
#
#    price_doc  room_size  ts_year  ts_dayofweek
# 0    5850000        NaN     2011             5
# 1    6000000        NaN     2011             1
# 2    5700000        NaN     2011             5
# 3   13100000        NaN     2011             3
# 4   16331452        NaN     2011             0
#
# [5 rows x 295 columns]

# %% [markdown]
# **Question 19: Draw histogram of price to see the distribution.**
#
# Hint: You can use matplotlib or pandas for this histogram.

# %%
df['price_doc'].hist(bins=100)

# %% [markdown]
# **Question 20: From the plot in Q15, most of the data have smaller values and the right tail of the distribution is very long. Apply a logorithm transformation to price and add this as a new feature called 'log_price'.**

# %%
df['log_price'] = np.log(df['price_doc'])
df.head()
# Out:
#    id   timestamp  full_sq  life_sq  floor  max_floor  material  build_year  \
# 0   1  2011-08-20       43     27.0    4.0        NaN       NaN         NaN
# 1   2  2011-08-23       34     19.0    3.0        NaN       NaN         NaN
# 2   3  2011-08-27       43     29.0    2.0        NaN       NaN         NaN
# 3   4  2011-09-01       89     50.0    9.0        NaN       NaN         NaN
# 4   5  2011-09-05       77     77.0    4.0        NaN       NaN         NaN
#
#    num_room  kitch_sq    ...      cafe_count_5000_price_high  \
# 0       NaN       NaN    ...                               0
# 1       NaN       NaN    ...                               0
# 2       NaN       NaN    ...                               0
# 3       NaN       NaN    ...                               1
# 4       NaN       NaN    ...                              17
#
#   big_church_count_5000 church_count_5000  mosque_count_5000  \
# 0                    13                22                  1
# 1                    15                29                  1
# 2                    11                27                  0
# 3                     4                 4                  0
# 4                   135               236                  2
#
#    leisure_count_5000  sport_count_5000  market_count_5000  price_doc  \
# 0                   0                52                  4    5850000
# 1                  10                66                 14    6000000
# 2                   4                67                 10    5700000
# 3                   0                26                  3   13100000
# 4                  91               195                 14   16331452
#
#    room_size  log_price
# 0        NaN  15.581952
# 1        NaN  15.607270
# 2        NaN  15.555977
# 3        NaN  16.388123
# 4        NaN  16.608603
#
# [5 rows x 294 columns]

# %%
plt.hist(df['log_price'], bins=100)
plt.show()

# %% [markdown]
# ** Question 21: Drop the log_price column.**

# %%
df = df.drop('log_price', axis=1)

# %% [markdown]
# **Question 22: Save the dataframe we have now to train_new.csv file**

# %%
df.to_csv('train_new.csv')

# %% [markdown]
# **Now you've finished basic data processing for Sberbank dataset.**
